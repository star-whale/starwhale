# %% [markdown]
# <a href="https://colab.research.google.com/github/star-whale/starwhale/blob/main/example/notebooks/quickstart-standalone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. 🍎 Installing Starwhale
#
# Starwhale has three types of instances: Standalone, Server, and Cloud. Starting with the standalone mode is ideal for quickly understanding and mastering Starwhale. You install Starwhale Standalone by running:

# %%
# %%bash
#
# python3 -m pip install starwhale
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 53.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 71.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.0/89.0 kB 10.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Getting Starwhale version and help info.

# %%
# %%bash
#
# swcli --version
# swcli --help
# Out:
# 0.6.5
# Usage: swcli [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   --version            Show the version and exit.
#   -v, --verbose        Show verbose log, support multi counts for v args. More
#                        v args, more logs.
#   -o, --output [json]  Output format
#   --help               Show this message and exit.
#
# Commands:
#   assistance     Remote assistance
#   board          A terminal based UI to interact with your starwhale...
#   check          Check external dependency software
#   completion     Shell completion for Starwhale command-line
#   config         Configuration management
#   dataset (ds)   Dataset management, build/info/list/copy/tag...
#   debug          debug cmds
#   gc             Standalone garbage collection
#   instance       Starwhale Instance management, login and select...
#   job            Job management, list/info/cancel/resume job
#   model (mp)     Model management, build/copy/run/list...
# ...

# %% [markdown]
# ## 2. 🍉 Downloading Examples
#
# Download Starwhale examples by cloning Starwhale via:

# %%
# %%bash
#
# [ -d "starwhale" ] || GIT_LFS_SKIP_SMUDGE=1 git clone https://github.com/star-whale/starwhale.git --depth 1
# cd starwhale
# git pull origin main
# Out:
# Already up to date.
# Cloning into 'starwhale'...
# From https://github.com/star-whale/starwhale
#  * branch            main       -> FETCH_HEAD

# %% [markdown]
# To save time in the example downloading, we skip git-lfs and other commits info. We will use ML/DL HelloWorld code `MNIST` to start your Starwhale journey. The following steps are all performed in the `starwhale` directory.

# %% [markdown]
# ## 3. 🍌 Building Runtime
#
# Runtime example code are in the `example/helloworld` directory.
#
# - Build the Starwhale Runtime bundle:

# %%
# %%bash
#
# cd starwhale
# swcli -vvv runtime build --yaml example/helloworld/runtime.yaml
# Out:
# [2023-11-23 07:39:59.299691] 👾 verbosity: 3, log level: DEBUG
# [2023-11-23 07:39:59.305333] 🚧 start to build runtime bundle...
# [2023-11-23 07:39:59.306693] ❓ |WARN| refine resource[ResourceType.runtime] helloworld/version/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd failed: Can not find the exact match item 2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd, found: []
# [2023-11-23 07:39:59.307911] 👷 uri local/project/self/runtime/helloworld/version/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd
# [2023-11-23 07:39:59.308646] 🐦 runtime will ignore pypi editable package
# [2023-11-23 07:39:59.310102] 👽 try to lock environment dependencies to /content/starwhale ...
# [2023-11-23 07:39:59.311403] 🦋 lock dependencies at mode venv
# [2023-11-23 07:39:59.312097] 🧮 setup python(3.10) env with venv...
# [2023-11-23 07:40:00.224285] 👏 create venv@/content/starwhale/.starwhale/venv, python:3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# ...

# %% [markdown]
# - Check your local Starwhale Runtime:

# %%
# %%bash
#
# export COLUMNS=150
# swcli runtime list
# swcli runtime info helloworld
# Out:
# ╭─ Starwhale Instance ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                ⭐ local (local) 🐳                                                                 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                                      Runtime List
#
#   Name             Version                                                 CreatedAt                         Size          Tags            Removed
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   helloworld       2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd                2023-11-23 07:40:49 UTC           20.00KiB      latest,v0       False
#
# ...

# %% [markdown]
# ## 4. 🥝 Building Model
#
# Model example code are in the `example/helloworld` directory.
#
# - Build a Starwhale Model with prebuilt Starwhale Runtime:

# %%
# %%bash
# cd starwhale
# swcli -vvv model build example/helloworld --name helloworld -m evaluation --runtime helloworld
# Out:
# [2023-11-23 07:41:15.116197] 👾 verbosity: 3, log level: DEBUG
# [2023-11-23 07:41:15.128056] 🦉 start to run in the new process with runtime environment: local/project/self/runtime/helloworld/version/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd
# [2023-11-23 07:41:15.130187] 🐌 start to restore runtime: local/project/self/runtime/helloworld/version/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd
# [2023-11-23 07:41:15.153768] 🧮 setup python(3.10) env with venv...
# [2023-11-23 07:41:15.430658] 👏 create venv@/root/.starwhale/self/workdir/runtime/helloworld/2p/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd/export/venv, python:3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]
# [2023-11-23 07:41:15.432412] 🍡 installing dependencies for pip_req_file:.starwhale/lock/requirements-sw-lock.txt in the venv environment
# ...

# %% [markdown]
# - Check your local Starwhale Model:

# %%
# %%bash
#
# export COLUMNS=150
# swcli model list
# swcli model info helloworld
# Out:
# ╭─ Starwhale Instance ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                ⭐ local (local) 🐳                                                                 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                                       Model List
#
#   Name         Version                         Project   Path                            Tags        CreatedAt                 IsRemoved   Size
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   helloworld   se34mgg6gs762krpshj2w2kwodka…   self      /root/.starwhale/self/model/…   latest,v0   2023-11-23 07:42:19 UTC   False       258.22KiB
#
# ...

# %% [markdown]
# ## 5. 🍊 Building Dataset
#
# Dataset example code are in the `example/helloworld` directory.
#
# - Build a Starwhale Dataset with prebuilt Starwhale Runtime:

# %%
# %%bash
#
# cd starwhale
# export COLUMNS=150
# swcli runtime activate helloworld
# python3 example/helloworld/dataset.py
# Out:
# 🥕 activate the current shell for the runtime uri: local/project/self/runtime/helloworld/version/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd
# [2023-11-23 07:42:44.362751] 👾 verbosity: 3, log level: DEBUG
# [2023-11-23 07:42:45.023326] ❓ |WARN| refine resource[ResourceType.dataset] mnist64/version/latest failed: Can not find the exact match item latest, found: []
# [2023-11-23 07:42:46.736556] 🔈 |DEBUG| dataset commit: revision-323050603469, info revision-
# local/project/self/dataset/mnist64/version/vs3gnaauakidjcc5effevaoh63vivu7dzodo5cmc dataset build done
# 100%|██████████| 259k/259k [00:00<00:00, 1.04MB/s]
# 100%|██████████| 500/500 [00:00<00:00, 2218.86it/s]

# %% [markdown]
# - Check your local Starwhale Dataset:

# %%
# %%bash
#
# export COLUMNS=150
# swcli dataset list
# swcli dataset info mnist64
# Out:
# ╭─ Starwhale Instance ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                ⭐ local (local) 🐳                                                                 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                                      Dataset List
#
#   Name          Version                                                    CreatedAt                          Tags            Size            Rows
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   mnist64       vs3gnaauakidjcc5effevaoh63vivu7dzodo5cmc                   2023-11-23 07:42:46 UTC            latest,v0       125.00KiB       500
#
# ...

# %% [markdown]
# - Head some records from the mnist dataset:

# %%
# %%bash
#
# export COLUMNS=150
# swcli dataset head mnist64
# Out:
# ╭─ Starwhale Instance ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                ⭐ local (local) 🐳                                                                 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# row [0] ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🌳 id: 0
# 🌀 features:
#          🔅 img : ArtifactType.Image, display:0, mime_type:MIMEType.PNG, shape:[8, 8, 1], encoding:
#          🔅 label : 0
#
# row [1] ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# 🌳 id: 1
# 🌀 features:
# ...

# %% [markdown]
# ## 6. 🥗 Running an Evaluation Job
#
# - Create an evaluation job:

# %%
# %%bash
#
# swcli -vvv model run --uri helloworld --dataset mnist64 --runtime helloworld
# Out:
# [2023-11-23 07:43:17.565003] 👾 verbosity: 3, log level: DEBUG
# [2023-11-23 07:43:17.596944] 🦉 start to run in the new process with runtime environment: local/project/self/runtime/helloworld/version/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd
# [2023-11-23 07:43:17.599562] 🐓 run process in the python isolated environment(prefix: /root/.starwhale/self/workdir/runtime/helloworld/2p/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd/export/venv)
# [2023-11-23 07:43:17.602706] 🔈 |DEBUG| cmd: ['bash', '-c', 'source /root/.starwhale/self/workdir/runtime/helloworld/2p/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd/export/venv/bin/activate && /root/.starwhale/self/workdir/runtime/helloworld/2p/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd/export/venv/bin/swcli -vvv model run --uri helloworld --dataset mnist64']
# [2023-11-23 07:43:20.388456] 👾 verbosity: 3, log level: DEBUG
# [2023-11-23 07:43:20.409991] ✈ change current dir to /root/.starwhale/self/job/ol/olxak7wbksiaspwm4d46kpebv6x3x2kpnkb5hcpt/snapshot
# ...

# %% [markdown]
# - Check the evaluation result:

# %%
# %%bash
#
# export COLUMNS=150
# swcli job list
# swcli job info $(swcli job list | grep mnist | grep success | awk '{print $1}' | head -n 1)
# Out:
# ╭─ Starwhale Instance ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                ⭐ local (local) 🐳                                                                 │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                                        Job List
#
#   ID                                         Model        Datasets   Runtime   Status      Resource   Created At              Finished At
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   olxak7wbksiaspwm4d46kpebv6x3x2kpnkb5hcpt   helloworld   mnist64    --        👏success   --         2023-11-23 07:43:20     2023-11-23 07:43:28
# ...

# %% [markdown]
# 👏 Now, you have completed the basic steps for Starwhale standalone.

# %% [markdown]
# ## 7. 🍇 Login Starwhale Cloud
#
# Starwhale Cloud is a managed service hosted on public clouds. By registering an account on <https://cloud.starwhale.cn>, you are ready to use Starwhale without needing to install, operate, and maintain your own instances. Starwhale Cloud also provides public resources for you to download, like datasets, runtimes, and models. Check the "starwhale/public" project on Starwhale Cloud for more details.
#
# When you already have an account, you can login it by `swcli` command:

# %%
# %%bash
#
# export COLUMNS=150
# swcli instance login --alias cloud-cn https://cloud.starwhale.cn/ --token "${token}"
# Out:
# 👨‍🍳 login https://cloud.starwhale.cn/ successfully!

# %% [markdown]
# Then you can manage the cloud instance by `swcli`:

# %%
# %%bash
# export COLUMNS=150
#
# # list instance
# swcli instance ls
#
# # list projects from cloud instance
# swcli project ls -i cloud-cn
#
# # list starwhale:public project' datasets form cloud instance
# swcli dataset list -p cloud://cloud-cn/project/starwhale:public
# Out:
#                                                                List Starwhale Instances
#
#   InUse      Name           Uri                                    UserName       UserRole      CurrentProject        UpdatedAt
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#              cloud-cn       https://cloud.starwhale.cn             tianwei        normal        --                    2023-11-23 07:44:17 UTC
#   👉         local          local                                  root           --            self                  2023-11-23 07:39:59 UTC
#
#                                                                Current Instance: local
#                                                                      Project List
#
#   InUse       Name                                                    Location        Owner                            CreatedAt
# ...

# %% [markdown]
# ## 8. 🍍 Copying to Starwhale Cloud
#
# Follow stpe3 to step5 to create:
#
#   - a Starwhale model named helloworld
#   - a Starwhale dataset named mnist64
#   - a Starwhale runtime named helloworld
#
# Now, we will copy the dataset, model and runtime to the Starwhale Cloud instance.
#
# You should create your project by Cloud Web UI:
# ![create project](https://starwhale-examples.oss-cn-beijing.aliyuncs.com/docs/cloud/create-project.png)

# %% [markdown]
# ### 🥕 Copying Starwhale Model

# %%
# %%bash
# export COLUMNS=150
#
# swcli model cp helloworld cloud-cn/project/starwhale:helloworld
# Out:
# 🚧 start to copy local/project/self/model/helloworld/version/se34mgg6gs762krpshj2w2kwodkakn2krf4tzjuk -> https://cloud.starwhale.cn/project/15/model/helloworld/version/se34mgg6gs762krpshj2w2kwodkakn2krf4tzjuk
# scanning se34mgg6gs762krpshj2w2kwodkakn2krf4tzjuk.swmp...
# scan done
# uploading metadata...
# metadata uploaded
#   ⬆ uploading se34mgg6gs762krpshj2w2kwodkakn2krf4tzjuk.swmp... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 273.7 kB 104.8 kB/s
#   ⬆ uploading the built-in runtime packaged.swrt               ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 20.5 kB  3.7 MB/s
# 🍵 console url of the remote bundle: https://cloud.starwhale.cn/projects/15/models/helloworld/versions/se34mgg6gs762krpshj2w2kwodkakn2krf4tzjuk/overview
# 🍵 no tags to copy
# 👏 copy done.

# %% [markdown]
# ### 🌶 Copying Starwhale Runtime

# %%
# %%bash
# export COLUMNS=150
#
# swcli runtime cp helloworld https://cloud.starwhale.cn/project/starwhale:helloworld
# Out:
# 🚧 start to copy local/project/self/runtime/helloworld/version/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd -> https://cloud.starwhale.cn/project/15/runtime/helloworld/version/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd
#   🎳 upload 2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd.swrt ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 20.5 kB 26.7 MB/s
# 🍵 console url of the remote bundle: https://cloud.starwhale.cn/projects/15/runtimes/helloworld/versions/2pbnjq2e22eycgfifltcrak6hkdsg2t5y57poqbd/overview
# 🍵 no tags to copy
# 👏 copy done.

# %% [markdown]
# ### 🥦 Copying Starwhale Dataset

# %%
# %%bash
# export COLUMNS=150
#
# swcli dataset cp mnist64 https://cloud.starwhale.cn/project/starwhale:helloworld
# Out:
# 🚧 start to copy local/project/self/dataset/mnist64/version/vs3gnaauakidjcc5effevaoh63vivu7dzodo5cmc -> https://cloud.starwhale.cn/project/15/dataset/mnist64/version/vs3gnaauakidjcc5effevaoh63vivu7dzodo5cmc
# 🐦 copy dataset rows
# ⠦ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500 0:00:01
# 🦘 update dataset info
# 🐯 make version for dest instance
# 🍵 console url of the remote bundle: https://cloud.starwhale.cn/projects/15/datasets/mnist64/versions/vs3gnaauakidjcc5effevaoh63vivu7dzodo5cmc/overview
# 🍵 no tags to copy
# 👏 copy done

# %% [markdown]
# ### 🫒 Checking Uploaded Model, Runtime and Dataset

# %%
# %%bash
# export COLUMNS=150
#
# swcli instance select cloud-cn
# swcli project select cloud-cn/project/starwhale:helloworld
#
# swcli model list
# swcli dataset list
# swcli runtime list
# Out:
# 👏 select cloud-cn instance
# 👏 select instance:cloud-cn, project:15 successfully
# ╭─ Starwhale Instance ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                    ⭐ cloud-cn (https://cloud.starwhale.cn) 🐳                                                     │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                                                                       Model List
#
#   Id      Name             CreatedTime          Owner        Version                                                Tags     Size           Shared
#  ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...

# %% [markdown]
# ## 🍱 Creating evaluation in Starwhale Cloud
#
# ![create evaluation](https://starwhale-examples.oss-cn-beijing.aliyuncs.com/docs/cloud/create-evaluation.gif)
#
# 🍺 Enjoy it.
